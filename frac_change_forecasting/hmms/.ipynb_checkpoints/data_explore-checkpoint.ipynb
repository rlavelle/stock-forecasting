# %%
from fastquant import get_stock_data
from hmmlearn import hmm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
def data_prep(data):
    df = pd.DataFrame(data=None, columns=['fracChange'])
    df['fracChange'] = (data['close']-data['open'])/data['open']

    return df

# %%
training_data = get_stock_data("AAPL", "2003-02-10", "2004-09-10")
testing_data = get_stock_data("AAPL", "2004-09-13", "2005-01-21")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
train = data_prep(training_data)

# %%
train.head()
# Out:
#             fracChange
# dt
# 2003-02-10    0.006311
# 2003-02-11   -0.010347
# 2003-02-12    0.008410
# 2003-02-13    0.009024
# 2003-02-14    0.004105

# %%
train['fracChange'].hist(figsize=(12,8),bins=150)

# %%
train['fracChange'].mean()
# Out:
# 0.002667422083201525

# %%
train['fracChange'].std()
# Out:
# 0.021241238692026366

# %%
_ = train.hist(figsize=(10,5), bins=150)

# %%
test = data_prep(testing_data)

# %%
test['fracChange'].hist(figsize=(12,8),bins=50)

# %%
training_data = get_stock_data("IBM", "2003-02-10", "2004-09-10")
testing_data = get_stock_data("IBM", "2004-09-13", "2005-01-21")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
train = data_prep(training_data)

# %%
train['fracChange'].hist(figsize=(12,8),bins=150)

# %%
{'ticker':'DPZ', 'start':'2009-01-01', 'end':'2015-01-01'}
# Out:
# {'ticker': 'DPZ', 'start': '2009-01-01', 'end': '2015-01-01'}

# %%
training_data = get_stock_data("DPZ", "2009-01-01", "2015-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
train = data_prep(training_data)

# %%
train['fracChange'].hist(figsize=(12,8),bins=150)

# %%
params = {'mu':train['fracChange'].mean(), 'std':train['fracChange'].std()}

# %%
samples = np.random.normal(loc=params['mu'], scale=params['std'], size=10000)

# %%
plt.hist(samples,bins=100)
plt.show()

# %%
samples.shape
# Out:
# (10000,)

# %%
np.arange(-0.2,0.2,0.4/10000).shape
# Out:
# (10000,)

# %%
training_data = get_stock_data("GME", "2019-01-01", "2021-04-22")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
train = data_prep(training_data)

# %%
train['fracChange'].hist(figsize=(12,8),bins=150)

# %%
params = {'mu':train['fracChange'].mean(), 'std':train['fracChange'].std()}

# %%
samples = np.random.normal(loc=params['mu'], scale=params['std'], size=10000)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.set_title('GME fracChange Distribution')
ax.hist(samples,bins=100)
ax.set_xlabel('fractional change')
# Out:
# Text(0.5, 0, 'fractional change')

# %%
def plot_hist(title, data):
    fig, ax = plt.subplots(figsize=(10,5))
    ax.set_title(title)
    ax.hist(data,bins=100)
    ax.set_xlabel('fractional change')
    plt.savefig(f'../imgs/{title}.png')

# %%
train = training_data['close'].values

# %%
from scipy.ndimage.filters import gaussian_filter
smoothed = gaussian_filter(train, sigma=10)
smoothed_2 = gaussian_filter(train, sigma=5)

# %%
fig, ax = plt.subplots(figsize=(25,10))
ax.set_title('AAPL data 2003-02-10 to 2004-09-10')
time = range(len(smoothed))
ax.plot(time,smoothed_2,color='tab:green',marker='s',markersize=2,linestyle='-',linewidth=1,label='gaussian smoother sigma=5')
ax.plot(time,smoothed,color='tab:red',marker='s',markersize=2,linestyle='-',linewidth=1,label='gaussian smoother sigma=10')
ax.plot(time,train,color='tab:blue',marker='s',markersize=2,linestyle='-',linewidth=1,label='actual')
ax.set_xlabel('time')
ax.set_ylabel('stock price ($)')
ax.set_xticks(np.arange(0,len(smoothed),25))
ax.set_xlim(0,len(smoothed)+10,)
ax.xaxis.grid(True,ls='--')
ax.yaxis.grid(True,ls='--')
ax.legend(prop={'size':20})
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = StandardScaler()
scaler = scaler.fit(train.reshape(-1,1))
train_scale = scaler.transform(train.reshape(-1,1))

# %%
from scipy.ndimage.filters import gaussian_filter
smoothed = gaussian_filter(train_scale, sigma=10)
smoothed_2 = gaussian_filter(train_scale, sigma=5)

# %%
fig, ax = plt.subplots(figsize=(25,10))
ax.set_title('AAPL data 2003-02-10 to 2004-09-10')
time = range(len(train_scale))
ax.plot(time,smoothed_2,color='tab:green',marker='s',markersize=2,linestyle='-',linewidth=1,label='gaussian smoother sigma=5')
ax.plot(time,smoothed,color='tab:red',marker='s',markersize=2,linestyle='-',linewidth=1,label='gaussian smoother sigma=10')
ax.plot(time,train_scale,color='tab:blue',marker='s',markersize=2,linestyle='-',linewidth=1,label='actual')
ax.set_xlabel('time')
ax.set_ylabel('stock price ($)')
ax.set_xticks(np.arange(0,len(train_scale),25))
ax.set_xlim(0,len(train_scale)+10,)
ax.xaxis.grid(True,ls='--')
ax.yaxis.grid(True,ls='--')
ax.legend(prop={'size':20})
plt.show()

# %%
train = get_stock_data('AAPL', '2020-01-01', '2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
test = get_stock_data('AAPL', '2021-01-01', '2021-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
train
# Out:
#                   open        high         low       close     volume
# dt
# 2020-01-02   74.059998   75.150002   73.797501   75.087502  135480400
# 2020-01-03   74.287498   75.144997   74.125000   74.357498  146322800
# 2020-01-06   73.447502   74.989998   73.187500   74.949997  118387200
# 2020-01-07   74.959999   75.224998   74.370003   74.597504  108872000
# 2020-01-08   74.290001   76.110001   74.290001   75.797501  132079200
# ...                ...         ...         ...         ...        ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001   54930100
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  124486200
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  121047300
# 2020-12-30  135.580002  135.990005  133.399994  133.720001   96452100
# 2020-12-31  134.080002  134.740005  131.720001  132.690002   99116600
#
# [253 rows x 5 columns]

# %%
test
# Out:
#                   open        high         low       close     volume
# dt
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  143301900
# 2021-01-05  128.889999  131.740005  128.429993  131.009995   97664900
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  155088000
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  109578200
# 2021-01-08  132.429993  132.630005  130.229996  132.050003  105158200
# ...                ...         ...         ...         ...        ...
# 2021-04-26  134.830002  135.059998  133.559998  134.720001   66905100
# 2021-04-27  135.009995  135.410004  134.110001  134.389999   66015800
# 2021-04-28  134.309998  135.020004  133.080002  133.580002  107760100
# 2021-04-29  136.470001  137.070007  132.449997  133.479996  151101000
# 2021-04-30  131.779999  133.559998  131.070007  131.460007  109713200
#
# [82 rows x 5 columns]

# %%
last = train.iloc[-1].to_dict()

# %%
last
# Out:
# {'open': 134.0800018310547,
#  'high': 134.74000549316406,
#  'low': 131.72000122070312,
#  'close': 132.69000244140625,
#  'volume': 99116600.0}

# %%
test = test.reset_index()

# %%
test
# Out:
#            dt        open        high         low       close     volume
# 0  2021-01-04  133.520004  133.610001  126.760002  129.410004  143301900
# 1  2021-01-05  128.889999  131.740005  128.429993  131.009995   97664900
# 2  2021-01-06  127.720001  131.050003  126.379997  126.599998  155088000
# 3  2021-01-07  128.360001  131.630005  127.860001  130.919998  109578200
# 4  2021-01-08  132.429993  132.630005  130.229996  132.050003  105158200
# ..        ...         ...         ...         ...         ...        ...
# 77 2021-04-26  134.830002  135.059998  133.559998  134.720001   66905100
# 78 2021-04-27  135.009995  135.410004  134.110001  134.389999   66015800
# 79 2021-04-28  134.309998  135.020004  133.080002  133.580002  107760100
# 80 2021-04-29  136.470001  137.070007  132.449997  133.479996  151101000
# 81 2021-04-30  131.779999  133.559998  131.070007  131.460007  109713200
#
# [82 rows x 6 columns]

# %%
row = pd.DataFrame(last, index=[0])

# %%
row['dt'] = None

# %%
row
# Out:
#          open        high         low       close      volume    dt
# 0  134.080002  134.740005  131.720001  132.690002  99116600.0  None

# %%
test = pd.concat([row,test], ignore_index=True)

# %%
test
# Out:
#           open        high         low       close       volume         dt
# 0   134.080002  134.740005  131.720001  132.690002   99116600.0        NaT
# 1   133.520004  133.610001  126.760002  129.410004  143301900.0 2021-01-04
# 2   128.889999  131.740005  128.429993  131.009995   97664900.0 2021-01-05
# 3   127.720001  131.050003  126.379997  126.599998  155088000.0 2021-01-06
# 4   128.360001  131.630005  127.860001  130.919998  109578200.0 2021-01-07
# ..         ...         ...         ...         ...          ...        ...
# 78  134.830002  135.059998  133.559998  134.720001   66905100.0 2021-04-26
# 79  135.009995  135.410004  134.110001  134.389999   66015800.0 2021-04-27
# 80  134.309998  135.020004  133.080002  133.580002  107760100.0 2021-04-28
# 81  136.470001  137.070007  132.449997  133.479996  151101000.0 2021-04-29
# 82  131.779999  133.559998  131.070007  131.460007  109713200.0 2021-04-30
#
# [83 rows x 6 columns]

# %%
get_stock_data('AAPL', '2021-05-11', '2021-05-12')
# Out:
# [*********************100%***********************]  1 of 1 completed
#              open        high         low   close    volume
# dt
# 2021-05-11  123.5  124.807198  122.779999  124.25  62562328

# %%
test['close'].pct_change().multiply(100).iloc[1:]
# Out:
# 1    -2.471926
# 2     1.236373
# 3    -3.366152
# 4     3.412322
# 5     0.863126
#         ...
# 78    0.297792
# 79   -0.244954
# 80   -0.602722
# 81   -0.074866
# 82   -1.513327
# Name: close, Length: 82, dtype: float64

# %%
from gaussian_hmm_close import *

# %%
params = {'n_components': 2, 
          'algorithm': 'map', 
          'n_iter': 100, 
          'd': 5,
          'name':'GHMM-CLOSE'}

# %%
ghmm = GHMM(params=params)

# %%
train = get_stock_data('AAPL', '2020-01-01', '2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
test = get_stock_data('AAPL', '2021-01-01', '2021-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ghmm.train(train)

# %%
preds, actual = ghmm.predict(test)
# Out:
# 4/83
# Process ForkPoolWorker-697:
# Process ForkPoolWorker-699:
# Process ForkPoolWorker-690:
# Process ForkPoolWorker-692:
# Process ForkPoolWorker-696:
# Process ForkPoolWorker-705:
# Process ForkPoolWorker-706:
# Process ForkPoolWorker-695:
# Process ForkPoolWorker-701:
# Process ForkPoolWorker-691:
# Process ForkPoolWorker-693:
# Process ForkPoolWorker-708:
# Process ForkPoolWorker-694:
# Process ForkPoolWorker-704:
# Process ForkPoolWorker-698:
# Process ForkPoolWorker-707:
# Process ForkPoolWorker-703:
# Process ForkPoolWorker-700:
# Process ForkPoolWorker-702:
# Process ForkPoolWorker-709:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib64/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib64/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
